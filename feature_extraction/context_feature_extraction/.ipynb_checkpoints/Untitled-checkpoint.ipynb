# %%
import pickle
with open('./document0.pickle', 'rb') as file:
            words_list = pickle.load(file)
            file.close()

# %%
import numpy as np

# %%
arr = np.array(words_list)
arr.
# Out:
# array([OrderedDict([('id', 1), ('form', 'Aus'), ('lemma', 'Aus'), ('upostag', None), ('xpostag', None), ('feats', None), ('head', None), ('deprel', None), ('deps', None), ('misc', None)]),
#        OrderedDict([('id', 2), ('form', 'dem'), ('lemma', 'dem'), ('upostag', None), ('xpostag', None), ('feats', None), ('head', None), ('deprel', None), ('deps', None), ('misc', None)]),
#        OrderedDict([('id', 3), ('form', 'Elfenbeinturm'), ('lemma', 'Elfenbeinturm'), ('upostag', None), ('xpostag', None), ('feats', None), ('head', None), ('deprel', None), ('deps', None), ('misc', None)]),
#        OrderedDict([('id', 4), ('form', 'Psychoanalyse'), ('lemma', 'Psychoanalyse'), ('upostag', None), ('xpostag', None), ('feats', None), ('head', None), ('deprel', None), ('deps', None), ('misc', None)]),
#        OrderedDict([('id', 5), ('form', 'im'), ('lemma', 'im'), ('upostag', None), ('xpostag', None), ('feats', None), ('head', None), ('deprel', None), ('deps', None), ('misc', None)]),
# ...

# %%
arr.shape
# Out:
# (521,)
