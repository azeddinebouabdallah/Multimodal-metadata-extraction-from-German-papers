# %%
import pickle

# %%
with open("layout_feature_extraction/word_lists/document0.pickle", 'rb') as file:
            words_list = pickle.load(file)
            file.close()

# %%
words_list
# Out:
# [['Aus'],
#  ['dem'],
#  ['Elfenbeinturm'],
#  ['Psychoanalyse'],
#  ['im'],
#  ['Grundstudium'],
#  ['\xad'],
#  ['Ihre'],
#  ['Bedeutung'],
#  ['für'],
#  ['Lernende'],
#  ['und'],
#  ['Lehrende'],
#  ['Hans-Dieter'],
#  ['Jena!'],
#  ['&'],
#  ['Eva'],
#  ['Jaeggi'],
#  ['In'],
#  ['einer'],
#  ['Diplomarbeit'],
#  ['der'],
#  ['Technischen'],
#  ['Bei'],
#  ['diesem'],
#  ['für'],
#  ['Schüler'],
#  ['doch'],
#  ['erstaunli\xad'],
#  ['Universität'],
#  ['Berlin'],
#  ['(Hans-Dieter'],
#  ['Jenal,'],
#  ['Psy\xad'],
#  ['chen'],
#  ['Wissensstand'],
#  ['ist'],
#  ['es'],
#  ['kein'],
#  ['Wunder,'],
#  ['daß'],
#  ['choanalyse'],
#  ['und'],
#  ['TUB.'],
#  ['Zur'],
#  ['Bedeutung'],
#  ['der'],
#  ['viele'],
#  ['die'],
#  ['Psychoanalyse'],
#  ['mit'],
#  ['der'],
#  ['Psychologie'],
#  ['Psychoanalyse'],
#  ['für'],
#  ['Studenten'],
#  ['der'],
#  ['Psychologie'],
#  ['ineinsgesetzt'],
#  ['haben'],
#  ['und'],
#  ['dementsprechend'],
#  ['im'],
#  ['Grundstudium'],
# ...
