# %%
# importing dataframe.xlsx file

import pandas as pd
#df = pd.read_excel("dataframe_engabstract.xlsx")
df = pd.read_excel("dataframe_gerabstract.xlsx")
df.head()
# Out:
#                                    author  \
# 0  Michael L. Brodie, Michael Stonebraker
# 1                            Frank Manola
# 2                            Frank Manola
# 3             Frank Manola, Sandra Heiler
# 4                            Frank Manola
#
#                                                title  \
# 0  DARWIN: On the Incremental Migration of Legacy...
# 1  Object Model Capabilities For Distributed Obje...
# 2  Integrating Object-Oriented Applications and M...
# 3  A RISC Object Model for Object System Interope...
# 4  MetaObject Protocol Concepts for a RISC Object...
#
#                                          affiliation  \
# 0                    Hochschule Albstadt-Sigmaringen
# 1  Fachhochschule für Verwaltung und Dienstleistu...
# 2  Ostbayerische Technische Hochschule Amberg-Weiden
# 3                Technische Hochschule Aschaffenburg
# 4  Fachhochschule Polizei Sachsen-Anhalt (Aschers...
#
#                                                email  \
# 0  michael_l._brodie@hochschule_albstadt_sigmarin...
# 1  frank_manola@fachhochschule_für_verwaltung_und...
# 2  frank_manola@ostbayerische_technische_hochschu...
# 3  frank_manola@technische_hochschule_aschaffenbu...
# 4  frank_manola@fachhochschule_polizei_sachsen_an...
#
#                                       GermanAbstract  year  \
# 0  befragungen von mitarbeitern der verwaltung ha...  1997
# 1  Acht Jahre nach der telefonischen Befragung vo...  2009
# 2  Das International Social Survey Programme (ISS...  2009
# 3  Das GESIS-IZ Sozialwissenschaften hat im Auftr...  2008
# 4  Die Studie präsentiert die Ergebnisse einer Be...  2005
#
#                                              journal  \
# 0  ZA-Information / Zentralarchiv für Empirische ...
# 1                                   ZUMA Nachrichten
# 2                                   ZUMA Nachrichten
# 3                                   ZUMA Nachrichten
# 4                                   ZUMA Nachrichten
#
#                                          doi                   street  \
# 0  https://doi.org/10.1080/00036840701736115  Schoenebergerstrasse 79
# 1  https://doi.org/10.1080/00036840701736115     Oldesloer Strasse 32
# 2  https://doi.org/10.1080/00036840701736115       Albrechtstrasse 84
# 3  https://doi.org/10.1080/00036840701736115     Gruenauer Strasse 59
# 4  https://doi.org/10.1080/00036840701736115            Prager Str 23
#
#         city    zip
# 0  Stralsund  18412
# 1       Suhl  98501
# 2    Nußdorf  83131
# 3  Buxtehude  21614
# 4    Weßling  82231

# %%
def generateAnnotationCsv(replaces, filelocation, template):

    # labels
    authorLabel = 1
    titleLabel = 2
    affilationLabel = 3
    dateLabel = 4
    journalLabel = 5
    addressLabel = 6
    abstractLabel = 7
    abstractLabel = 7
    doiLabel = 8
    emailLabel = 9
    otherLabel = 10

    annotation = []
    # Creating csv based on the order and length of replaces in template
    # TODO: Other Label if there is unknown amount of text left
    if template == '6041.docx':
        print("Template " + template + " found")
        authorLen = len(replaces[0].split())
        titleLen = len(replaces[1].split())
        gerintroductionLen = len(replaces[7].split())

        annotations = authorLen * [authorLabel] + titleLen * [titleLabel] + gerintroductionLen * [abstractLabel]
        #Rest is other label

    elif template == '11258.docx':
         print("Template " + template + " found")
         journalLen = len(replaces[4].split())
         dateLen = len(replaces[3].split())
         titleLen = len(replaces[1].split())
         authorLen = len(replaces[0].split())
         affilationLen = len(replaces[2].split())
         addressLen = len(replaces[5].split())

         annotations = journalLen * [journalLabel] + dateLen * [dateLabel] + titleLen * [titleLabel] + authorLen * [authorLabel] + affilationLen * [affilationLabel] + addressLen * [addressLabel]

    elif template == '11721.docx':
        print("Template " + template + " found")
        journalLen = len(replaces[4].split())
        authorLen = len(replaces[0].split())
        addressLen = len(replaces[5].split())
        doiLen = len(replaces[8].split())

        annotations = journalLen * [journalLabel] + 4 * [otherLabel] + authorLen * [authorLabel] + 25 * [otherLabel] + addressLen * [addressLabel] + 10 * [otherLabel] + doiLen * [doiLabel]
        
    else:
        print("No information about this template")


    if len(annotations) > 0:
        df = pd.DataFrame(annotations, columns=['Label'])
    else:
        df = pd.DataFrame([], columns=['Label'])

    df.to_csv(filelocation)

# %% [markdown]
# ## Generating Data in form of .docx files

# %%
# generating new data from template in the form of docx files 
import re
from docx import Document
from docx2pdf import convert  ##only works on Windows
import os

temp = ""
# function to replace text in docx file
def docx_replace_regex(doc_obj, regex , replace, temp):   
    # p variable refers to paragraph below
    for p in doc_obj.paragraphs:
        inline = p.runs     
        if regex in p.text:            
            for i in range(len(inline)):                
                temp = temp + inline[i].text
                if regex in temp:
                    if replace=="na":
                        continue 
                    else:
                        temp = temp.replace(regex, replace)
                        inline[i].text=temp        

# print function to check the layout of word file 
def printf (doc_obj):  
    for p in doc_obj.paragraphs:
        if p.text=='':
            continue
        else:
            print(p.text)
    print("\n")

# put the text you want to replace here, depending on how many classes of metadata is in that template

text_to_replace1 = "author"
text_to_replace2 = "title"
text_to_replace3 = "affiliation"
text_to_replace4 = "date"
text_to_replace5 = "journal"
text_to_replace6 = "address"
text_to_replace7 = "engintroduction"
text_to_replace8 = "gerintroduction"
text_to_replace9 = "doi"
text_to_replace10 = "email"


# select data from dataframe to replace with
count=0
number=0
stopnumber=0

templates_folder_name = 'templates/'

for file in os.scandir(templates_folder_name):
    if file.is_file():
        for row in df.index:
            replace1 = df['author'][count]
            replace2 = df['title'][count]
            replace3 = df['affiliation'][count]
            replace4 = str(df['year'][count])
            replace5 = df['journal'][count]
            replace6 = df['street'][count]
            try:
              replace7 = df['EnglishAbstract'][count]
            except KeyError:
              replace7 = ''  
            try:
              replace8 = df['GermanAbstract'][count]
            except KeyError:
              replace8 = ''

            replace9 = df['doi'][count]
            replace10 = df['email'][count]

            count=count+1

            ############### put the template docx file name here to read  ########################
            filename = file.name
            doc = Document("templates/" + filename)
            docx_replace_regex(doc, text_to_replace1 , replace1, temp)
            docx_replace_regex(doc, text_to_replace2 , replace2, temp)
            docx_replace_regex(doc, text_to_replace3 , replace3, temp)
            docx_replace_regex(doc, text_to_replace4 , replace4, temp)
            docx_replace_regex(doc, text_to_replace5 , replace5, temp)
            docx_replace_regex(doc, text_to_replace6 , replace6, temp)
            docx_replace_regex(doc, text_to_replace7 , replace7, temp)
            docx_replace_regex(doc, text_to_replace8 , replace8, temp)
            docx_replace_regex(doc, text_to_replace9 , replace9, temp)
            docx_replace_regex(doc, text_to_replace10 , replace10, temp)

            # TODO: Randomize some of the tempaltes e.g. pageNumbers, articleNumber in Journal, Address of publisher etc.
            #printf (doc)
            #print(" \n ---------------------------------------------------------------------------------------- \n")

            # save the generated file
            doc_filename = filename.split('.')[0] + '_' + str(number) +  '.docx'
            pdf_filename = filename.split('.')[0] + '_' + str(number) +  '.pdf'
            csv_filename = filename.split('.')[0] + '_' + str(number) +  '.csv'
            folder = 'generated_docs/'
            pdffolder = 'generated_pdfs/'
            annotationfolder = 'generated_annotations/'
            doc.save(folder+doc_filename)
            number = number+1
            stopnumber=stopnumber+1

            #convert(folder + doc_filename, pdffolder + pdf_filename) #(this can be enabled on Windows to generate the pdf too)


            generateAnnotationCsv([replace1, replace2, replace3, replace4, replace5, replace6, replace7, replace8, replace9, replace10], annotationfolder + csv_filename,filename)


            # put the stop number to how many files you want to generate
            if stopnumber==5:
                break


            #convert(folder + doc_filename, pdffolder + pdf_filename) #(this can be enabled on Windows to generate the pdf too)
            #oowriter -convert-to pdf:writer_pdf_Export *.docx (linux alternative command)
# Out:
# Template 11258.docx found
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-5-c2cb019bb66f> in <module>
#     114
#     115
# --> 116             convert(folder + doc_filename, pdffolder + pdf_filename) #(this can be enabled on Windows to generate the pdf too)
#     117             #oowriter -convert-to pdf:writer_pdf_Export *.docx (linux alternative command)
#
# ~/anaconda3/lib/python3.7/site-packages/docx2pdf/__init__.py in convert(input_path, output_path, keep_active)
#     107     else:
#     108         raise NotImplementedError(
# --> 109             "docx2pdf is not implemented for linux as it requires Microsoft Word to be installed"
#     110         )
#     111
#
# NotImplementedError: docx2pdf is not implemented for linux as it requires Microsoft Word to be installed

# %% [markdown]
# ## Save only the first page

# %%
from PyPDF2 import PdfFileReader, PdfFileWriter
import os

#Save only the first page    
current_path = os.getcwd()
print(current_path)
dataset_folder_name = current_path + '/generated_pdfs/'
result_folder = current_path + '/generated_pdfs/'

for file in os.scandir(dataset_folder_name):
    if (file.path.endswith('.pdf')) and file.is_file():

        pdf = PdfFileReader(file.path)
        pdfWriter = PdfFileWriter()
        pdfWriter.addPage(pdf.getPage(0))
        new_path = result_folder + file.name
        print(new_path)
        f = open(result_folder +  file.name, 'wb')
        pdfWriter.write(f)
        f.close()
# Out:
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1208.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1052.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1188.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1094.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1048.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1023.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1147.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1070.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1195.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1142.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1057.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1126.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_10.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1006.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1162.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1161.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1175.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1136.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1042.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1203.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1204.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1122.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1117.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/6041_3.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1111.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1074.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_11.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1157.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1150.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1158.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11258_4.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1168.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_119.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1152.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1173.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1193.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1087.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1033.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1171.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1051.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1156.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_118.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1016.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1145.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1194.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1201.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1160.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1005.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1027.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_2.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_111.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11258_2.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1014.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1135.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1120.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1004.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1210.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1097.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1113.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1002.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1132.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1055.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_107.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1121.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1043.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1049.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1008.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1047.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1166.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11258_3.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1186.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11258_0.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1041.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1141.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1079.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1165.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1154.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1124.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1144.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_115.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1083.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1155.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1105.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1172.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1108.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1031.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1054.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1060.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_114.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1196.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1085.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_100.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/6041_4.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1218.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1213.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1128.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1146.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1103.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1114.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1177.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1217.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/6041_0.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1011.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1007.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1046.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1075.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1127.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1062.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1115.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1110.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1174.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1214.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1119.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1061.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1202.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1170.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1107.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1163.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1130.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1059.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1216.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1129.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1030.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1123.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_117.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1086.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1205.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_4.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1116.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1137.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_110.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1199.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1206.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1112.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1026.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1211.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1034.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1037.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1149.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1184.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1118.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1164.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1092.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/6041_1.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1093.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_113.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1068.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1022.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_108.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1010.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1125.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1063.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_109.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1106.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1053.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1013.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1064.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1180.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1178.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1134.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1082.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1009.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1090.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1140.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1187.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1096.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_106.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1185.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1066.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1045.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1040.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1032.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1207.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1198.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1181.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1056.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1183.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1071.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_103.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1069.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1215.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1197.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_3.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1179.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1109.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1212.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1065.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1176.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_0.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1038.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1089.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1091.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1169.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1102.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1015.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1067.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1148.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_112.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1209.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1035.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1133.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1001.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1084.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1018.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1081.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1159.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1078.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1143.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1000.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1182.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1080.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_121.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1153.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1138.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1191.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1095.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1024.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1151.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1104.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1073.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_120.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1017.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1099.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11258_1.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1012.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1100.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1036.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/6041_2.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1088.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1076.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1139.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1025.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1192.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1189.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_116.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1200.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_104.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1131.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1058.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1098.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_105.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1019.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1021.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1003.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1044.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_102.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1039.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1219.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1020.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1101.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1077.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_101.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1072.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1050.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1028.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1167.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1190.pdf
# /home/azeddine/Dropbox/University/Winter semester 20-21/Machine learning application/research-lab-ml/data_generation/generated_pdfs/11721_1029.pdf
